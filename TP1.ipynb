# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np


# file_path = "./dataset/home-credit-default-risk/application_test.csv"
df = pd.read_csv(r"dataset\home-credit-default-risk\application_train.csv")

print(df["TARGET"].value_counts())
# Out:
# TARGET
# 0    282686
# 1     24825
# Name: count, dtype: int64
